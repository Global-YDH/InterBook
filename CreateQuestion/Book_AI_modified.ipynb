# %%
import os
import shutil

def recursive_unpack(filename, extract_dir):
    try:
        # 지정된 파일을 압축 해제
        shutil.unpack_archive(filename, extract_dir)
        print(f"Unpacked: {filename} to {extract_dir}")
    except (shutil.ReadError, ValueError) as e:
        print(f"Failed to unpack {filename}: {e}")
        return

    # 해제된 디렉토리 내의 파일을 탐색하여 중첩 압축 파일 처리
    for root, dirs, files in os.walk(extract_dir):
        for file in files:
            file_path = os.path.join(root, file)
            if any(file_path.endswith(ext) for ext in ['.zip', '.tar.gz', '.tgz', '.tar']):
                new_extract_dir = os.path.join(root, file.rsplit(".", 1)[0])
                os.makedirs(new_extract_dir, exist_ok=True)
                recursive_unpack(file_path, new_extract_dir)
                os.remove(file_path)  # 중첩 압축 파일 삭제 (선택 사항)

# Data 폴더 내의 최상위 압축 파일 해제 및 모든 중첩 압축 파일 해제
data_dir = '/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data'
for file in os.listdir(data_dir):
    file_path = os.path.join(data_dir, file)
    if any(file_path.endswith(ext) for ext in ['.zip', '.tar.gz', '.tgz', '.tar']):
        extract_dir = os.path.join(data_dir, file.rsplit(".", 1)[0])
        os.makedirs(extract_dir, exist_ok=True)
        recursive_unpack(file_path, extract_dir)
# Out:
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_04T_예술경험_02S_초등_저학년.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_04T_예술경험_02S_초등_저학년
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_01T_의사소통_03S_초등_고학년.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_01T_의사소통_03S_초등_고학년
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_04T_예술경험_01S_유아.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_04T_예술경험_01S_유아
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_03T_사회관계_01S_유아.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_03T_사회관계_01S_유아
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_01T_의사소통_01S_유아.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_01T_의사소통_01S_유아
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_05T_신체운동_건강_01S_유아.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_05T_신체운동_건강_01S_유아
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_04T_예술경험_03S_초등_고학년.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_04T_예술경험_03S_초등_고학년
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_05T_신체운동_건강_02S_초등_저학년.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_05T_신체운동_건강_02S_초등_저학년
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_02T_자연탐구_02S_초등_저학년.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_02T_자연탐구_02S_초등_저학년
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_03T_사회관계_03S_초등_고학년.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_03T_사회관계_03S_초등_고학년
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_01T_의사소통_02S_초등_저학년.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_01T_의사소통_02S_초등_저학년
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_02T_자연탐구_01S_유아.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_02T_자연탐구_01S_유아
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_02T_자연탐구_03S_초등_고학년.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_02T_자연탐구_03S_초등_고학년
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_05T_신체운동_건강_03S_초등_고학년.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_05T_신체운동_건강_03S_초등_고학년
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_03T_사회관계_02S_초등_저학년.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터/TS_03T_사회관계_02S_초등_저학년
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/740.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/740
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/540.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/540
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/700.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/700
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/960.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/960
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/800.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/800
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/560.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/560
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/610.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/610
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/320.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/320
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/580.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/580
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/950.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/950
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/400.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/400
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/870.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/870
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/810.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/810
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/910.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/910
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/380.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/380
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/710.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/710
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/890.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/890
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/980.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/980
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/660.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/660
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/850.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/850
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/510.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/510
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/520.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/520
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/880.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/880
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/480.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/480
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/900.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/900
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/680.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/680
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/990.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/990
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/530.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/530
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/830.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/830
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/860.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/860
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/420.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/420
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/440.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/440
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/590.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/590
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/490.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/490
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/940.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/940
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/650.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/650
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/390.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/390
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/730.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/730
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/500.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/500
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/630.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/630
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/570.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/570
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/690.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/690
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/470.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/470
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/370.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/370
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/640.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/640
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/430.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/430
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/360.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/360
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/600.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/600
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/450.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/450
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/920.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/920
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/550.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/550
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/670.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/670
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/820.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/820
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/410.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/410
# Unpacked: /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/840.zip to /home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble/840

# %%
import os
import json
import pandas as pd
from datasets import Dataset, concatenate_datasets
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer
from peft import LoraConfig, get_peft_model, TaskType
from transformers import BitsAndBytesConfig
import torch
import gc
from torch.nn import CrossEntropyLoss
# Out:
# /home/dnslabs/miniconda3/envs/ryu/lib/python3.11/site-packages/torchvision/datapoints/__init__.py:12: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /home/dnslabs/miniconda3/envs/ryu/lib/python3.11/site-packages/torchvision/transforms/v2/__init__.py:54: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)

# %%
# 데이터 파일 경로 설정
fairytale_folder = "/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/RowData/01.원천데이터"
book_folder = "/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/Data/TL_unscramble"

# Hugging Face 액세스 토큰
# token = "***************************"

# JSON 파일에서 텍스트 추출
texts = []

for root, dirs, files in os.walk(fairytale_folder):
    for file_name in files:
        if file_name.endswith('.json'):
            file_path = os.path.join(root, file_name)
            with open(file_path, 'r', encoding='utf-8-sig') as json_file:
                json_data = json.load(json_file)
                for paragraph in json_data.get("paragraphInfo", []):
                    texts.append(paragraph["srcText"])
for root, dirs, files in os.walk(book_folder):
    for file_name in files:
        if file_name.endswith('.json'):
            file_path = os.path.join(root, file_name)
            with open(file_path, 'r', encoding='utf-8-sig') as json_file:
                json_data = json.load(json_file)
                for paragraph in json_data.get("paragraphs", []):
                    for sentence in paragraph.get("sentences", []):
                        texts.append(sentence["text"])

df = pd.DataFrame(texts, columns=["text"])
dataset = Dataset.from_pandas(df)

# %%
# Hugging Face 모델과 토크나이저 로드
model_name = "meta-llama/Llama-3.2-1B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

# 토크나이징 함수 정의 (동적 패딩 적용, max_length 없이 설정)
def tokenize_function(examples):
    return tokenizer(examples["text"], padding="longest", truncation=True)

# 청크 저장 폴더 생성
output_dir = "/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/model/temp_data"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 데이터셋 청크 단위로 토크나이징 및 저장
num_chunks = 50

# 주석된 부분 활성화하여 청크 저장
# for i in range(num_chunks):
#     dataset_chunk = dataset.select(range(start_idx, end_idx))
    
#     tokenized_chunk = dataset_chunk.map(
#         tokenize_function,
#         batched=True,
#         batch_size=8,
#         keep_in_memory=False,
#         writer_batch_size=1
#     )
    
#     chunk_path = os.path.join(output_dir, f"tokenized_chunk_{i}")
#     tokenized_chunk.save_to_disk(chunk_path)
#     del dataset_chunk, tokenized_chunk
#     gc.collect()
#     torch.cuda.empty_cache()

tokenized_datasets = [Dataset.load_from_disk(os.path.join(output_dir, f"tokenized_chunk_{i}")) for i in range(num_chunks)]
final_tokenized_dataset = concatenate_datasets(tokenized_datasets)

# 20% 데이터로 파인튜닝, 80% 데이터로 학습
train_split = final_tokenized_dataset.train_test_split(test_size=0.8, seed=42)
finetune_dataset = train_split["train"]
remaining_data = train_split["test"]

# remaining_data를 train, validation, test로 분할
remaining_split = remaining_data.train_test_split(test_size=0.3, seed=42)  # 70% 학습 데이터, 나머지 30%는 validation과 test로 사용
validation_test_split = remaining_split["test"].train_test_split(test_size=1/3, seed=42)  # 30% 중 1/3은 test, 나머지 2/3은 validation

train_dataset = remaining_split["train"]  # 70%
validation_dataset = validation_test_split["train"]  # 20%
test_dataset = validation_test_split["test"]  # 10%

# %%
# 양자화 및 모델 로드 설정
quantization_config = BitsAndBytesConfig(load_in_8bit=True)
model = AutoModelForCausalLM.from_pretrained(model_name, quantization_config=quantization_config, device_map="auto")

# LoRA 설정 및 적용
lora_config = LoraConfig(task_type=TaskType.CAUSAL_LM, inference_mode=False, r=16, lora_alpha=32, lora_dropout=0.05)
model = get_peft_model(model, lora_config)

# CustomTrainer 클래스 정의
class CustomTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs["input_ids"]
        outputs = model(**inputs)
        logits = outputs.get("logits")
        
        shift_logits = logits[..., :-1, :].contiguous()
        shift_labels = labels[..., 1:].contiguous()
        loss_fct = CrossEntropyLoss()
        loss = loss_fct(shift_logits.view(-1, shift_logits.size(-1)), shift_labels.view(-1))
        
        return (loss, outputs) if return_outputs else loss

# 학습 파라미터 설정 (평가 생략)
training_args = TrainingArguments(
    output_dir="/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/model/llama_finetuned_finetune",
    overwrite_output_dir=True,  # 기존 설정 덮어쓰기
    eval_strategy="no",  # 평가를 생략하여 속도 향상
    learning_rate=1e-4,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    num_train_epochs=1,
    weight_decay=0.01,
    logging_dir='/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/model/logs',
    fp16=True,
)

# # 전체 학습 스텝 계산 후 절반으로 로깅 및 체크포인트 설정
# total_steps = len(train_dataset) // training_args.per_device_train_batch_size * training_args.num_train_epochs
# training_args.logging_steps = total_steps // 2  # 전체 스텝의 절반
# training_args.save_steps = total_steps // 2     # 전체 스텝의 절반

# 파인튜닝 (20% 데이터 사용)
finetune_trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=finetune_dataset,  # 20% 데이터셋
    eval_dataset=validation_dataset
)

checkpoint_dir = "/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/model/llama_finetuned_finetune"

# 마지막 체크포인트가 있는지 확인 후 이어서 학습 시작
if os.path.exists(checkpoint_dir) and len(os.listdir(checkpoint_dir)) > 0:
    finetune_trainer.train(resume_from_checkpoint=False)
else:
    finetune_trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: 1112hoya (Globals). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/wandb/run-20241109_231055-spkj22g2</code>
# Syncing run <strong><a href='https://wandb.ai/Globals/huggingface/runs/spkj22g2' target="_blank">/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/model/llama_finetuned_finetune</a></strong> to <a href='https://wandb.ai/Globals/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/Globals/huggingface' target="_blank">https://wandb.ai/Globals/huggingface</a>
#  View run at <a href='https://wandb.ai/Globals/huggingface/runs/spkj22g2' target="_blank">https://wandb.ai/Globals/huggingface/runs/spkj22g2</a>
#     <div>
#
#       <progress value='119457' max='119457' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [119457/119457 20:04:36, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.212200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.043000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.026000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.022000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.023400</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.021900</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>1.010200</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.011200</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>1.005800</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.992100</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.994300</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>1.004800</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.990600</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.991800</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.988000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.993200</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.986300</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.994800</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.977600</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.978500</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.983500</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.969200</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.976900</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.978600</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.986100</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.966600</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.973000</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.974200</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.982900</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.966600</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.973600</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.971000</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.972200</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.966300</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.970100</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.967200</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>0.974400</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.969700</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.968700</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.967500</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>0.964700</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>0.975100</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>0.970200</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.957300</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>0.969200</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>0.969200</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>0.973400</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.962400</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>0.963700</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>0.958700</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>0.960800</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>0.962900</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>0.960600</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>0.971800</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>0.976900</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>0.959000</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>0.965500</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>0.956000</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>0.967100</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>0.960000</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>0.958500</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>0.960000</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>0.962200</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>0.956100</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>0.950300</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>0.964600</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>0.955700</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>0.957700</td>
#     </tr>
#     <tr>
#       <td>34500</td>
#       <td>0.952700</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>0.951400</td>
#     </tr>
#     <tr>
#       <td>35500</td>
#       <td>0.953600</td>
#     </tr>
#     <tr>
#       <td>36000</td>
#       <td>0.960500</td>
#     </tr>
#     <tr>
#       <td>36500</td>
#       <td>0.955700</td>
#     </tr>
#     <tr>
#       <td>37000</td>
#       <td>0.958500</td>
#     </tr>
#     <tr>
#       <td>37500</td>
#       <td>0.954100</td>
#     </tr>
#     <tr>
#       <td>38000</td>
#       <td>0.954700</td>
#     </tr>
#     <tr>
#       <td>38500</td>
#       <td>0.957200</td>
#     </tr>
#     <tr>
#       <td>39000</td>
#       <td>0.951000</td>
#     </tr>
#     <tr>
#       <td>39500</td>
#       <td>0.956000</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>0.949000</td>
#     </tr>
#     <tr>
#       <td>40500</td>
#       <td>0.971000</td>
#     </tr>
#     <tr>
#       <td>41000</td>
#       <td>0.963800</td>
#     </tr>
#     <tr>
#       <td>41500</td>
#       <td>0.946700</td>
#     </tr>
#     <tr>
#       <td>42000</td>
#       <td>0.961000</td>
#     </tr>
#     <tr>
#       <td>42500</td>
#       <td>0.944800</td>
#     </tr>
#     <tr>
#       <td>43000</td>
#       <td>0.957300</td>
#     </tr>
#     <tr>
#       <td>43500</td>
#       <td>0.951700</td>
#     </tr>
#     <tr>
#       <td>44000</td>
#       <td>0.957700</td>
#     </tr>
#     <tr>
#       <td>44500</td>
#       <td>0.959800</td>
#     </tr>
#     <tr>
#       <td>45000</td>
#       <td>0.944800</td>
#     </tr>
#     <tr>
#       <td>45500</td>
#       <td>0.956500</td>
#     </tr>
#     <tr>
#       <td>46000</td>
#       <td>0.954900</td>
#     </tr>
#     <tr>
#       <td>46500</td>
#       <td>0.955600</td>
#     </tr>
#     <tr>
#       <td>47000</td>
#       <td>0.947700</td>
#     </tr>
#     <tr>
#       <td>47500</td>
#       <td>0.956200</td>
#     </tr>
#     <tr>
#       <td>48000</td>
#       <td>0.953500</td>
#     </tr>
#     <tr>
#       <td>48500</td>
#       <td>0.959400</td>
#     </tr>
#     <tr>
#       <td>49000</td>
#       <td>0.955300</td>
#     </tr>
#     <tr>
#       <td>49500</td>
#       <td>0.951800</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>0.957500</td>
#     </tr>
#     <tr>
#       <td>50500</td>
#       <td>0.949300</td>
#     </tr>
#     <tr>
#       <td>51000</td>
#       <td>0.957100</td>
#     </tr>
#     <tr>
#       <td>51500</td>
#       <td>0.954500</td>
#     </tr>
#     <tr>
#       <td>52000</td>
#       <td>0.940600</td>
#     </tr>
#     <tr>
#       <td>52500</td>
#       <td>0.939900</td>
#     </tr>
#     <tr>
#       <td>53000</td>
#       <td>0.951100</td>
#     </tr>
#     <tr>
#       <td>53500</td>
#       <td>0.957600</td>
#     </tr>
#     <tr>
#       <td>54000</td>
#       <td>0.953100</td>
#     </tr>
#     <tr>
#       <td>54500</td>
#       <td>0.959300</td>
#     </tr>
#     <tr>
#       <td>55000</td>
#       <td>0.946800</td>
#     </tr>
#     <tr>
#       <td>55500</td>
#       <td>0.949200</td>
#     </tr>
#     <tr>
#       <td>56000</td>
#       <td>0.944800</td>
#     </tr>
#     <tr>
#       <td>56500</td>
#       <td>0.944800</td>
#     </tr>
#     <tr>
#       <td>57000</td>
#       <td>0.962000</td>
#     </tr>
#     <tr>
#       <td>57500</td>
#       <td>0.948400</td>
#     </tr>
#     <tr>
#       <td>58000</td>
#       <td>0.951200</td>
#     </tr>
#     <tr>
#       <td>58500</td>
#       <td>0.941900</td>
#     </tr>
#     <tr>
#       <td>59000</td>
#       <td>0.941600</td>
#     </tr>
#     <tr>
#       <td>59500</td>
#       <td>0.945900</td>
#     </tr>
#     <tr>
#       <td>60000</td>
#       <td>0.941100</td>
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>train/global_step</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇█</td></tr><tr><td>train/grad_norm</td><td>▁▃▃▃▅▄▅▅▃▇▆▃▄▄▆▂▅▅▆▇▆▆▅▆▄▅▃▇▅▅▆▇█▅▇▄▆▆█▅</td></tr><tr><td>train/learning_rate</td><td>██▇▇▇▇▆▆▆▆▆▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▆▆▅▆▄▄▄▄▄▃▄▃▂▂▃▂▃▂▃▃▂▂▃▂▂▂▂▂▂▂▁▂▂▁▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>total_flos</td><td>2.8619219087114895e+18</td></tr><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/global_step</td><td>119457</td></tr><tr><td>train/grad_norm</td><td>0.51817</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.9323</td></tr><tr><td>train_loss</td><td>0.95557</td></tr><tr><td>train_runtime</td><td>72280.6175</td></tr><tr><td>train_samples_per_second</td><td>52.886</td></tr><tr><td>train_steps_per_second</td><td>1.653</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/model/llama_finetuned_finetune</strong> at: <a href='https://wandb.ai/Globals/huggingface/runs/spkj22g2' target="_blank">https://wandb.ai/Globals/huggingface/runs/spkj22g2</a><br/> View project at: <a href='https://wandb.ai/Globals/huggingface' target="_blank">https://wandb.ai/Globals/huggingface</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241109_231055-spkj22g2/logs</code>

# %%
finetune_trainer.save_model("/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/model/llama_finetuned_finetune")

# %%
# 파인튜닝된 모델 불러오기 (finetune_model로 설정)
finetune_model = AutoModelForCausalLM.from_pretrained("/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/model/llama_finetuned_finetune", quantization_config=quantization_config, device_map="auto")
finetune_model = get_peft_model(finetune_model, lora_config)

# 최종 학습 (80% 데이터 사용)
trainer = CustomTrainer(
    model=finetune_model,
    args=training_args,
    train_dataset=train_dataset,  # 80% 데이터셋
    eval_dataset=validation_dataset
)

# 최종 학습 수행 및 모델 저장
trainer.train()
trainer.save_model("/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/model/llama_finetuned_final")
# Out:
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/wandb/run-20241110_191855-soo36xbe</code>
# Syncing run <strong><a href='https://wandb.ai/Globals/huggingface/runs/soo36xbe' target="_blank">/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/model/llama_finetuned_finetune</a></strong> to <a href='https://wandb.ai/Globals/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/Globals/huggingface' target="_blank">https://wandb.ai/Globals/huggingface</a>
#  View run at <a href='https://wandb.ai/Globals/huggingface/runs/soo36xbe' target="_blank">https://wandb.ai/Globals/huggingface/runs/soo36xbe</a>
#     <div>
#
#       <progress value='276366' max='334478' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [276366/334478 46:44:08 < 9:49:38, 1.64 it/s, Epoch 0.83/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.224900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.044400</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.029800</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.026800</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.023100</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.012500</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>1.006500</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.002700</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>1.004200</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.988700</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>1.005400</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>1.002900</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.989000</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.987800</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.979600</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.983100</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.985100</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.992200</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.985600</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.983000</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.971900</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.967300</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.979400</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.981200</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.972300</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.982600</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.978100</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.976200</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.975100</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.968300</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.972200</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.972100</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.979400</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.974900</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.967100</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>0.969500</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.973800</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.972800</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.969700</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>0.973100</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>0.960500</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>0.961800</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.972200</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>0.971600</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>0.966600</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>0.956400</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.963100</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>0.967900</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>0.960500</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>0.962100</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>0.956100</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>0.973100</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>0.961500</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>0.961700</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>0.956900</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>0.961000</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>0.959000</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>0.964300</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>0.969100</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>0.961600</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>0.956000</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>0.952700</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>0.970500</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>0.962800</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>0.969500</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>0.959400</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>0.959400</td>
#     </tr>
#     <tr>
#       <td>34500</td>
#       <td>0.956600</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>0.955900</td>
#     </tr>
#     <tr>
#       <td>35500</td>
#       <td>0.959100</td>
#     </tr>
#     <tr>
#       <td>36000</td>
#       <td>0.954100</td>
#     </tr>
#     <tr>
#       <td>36500</td>
#       <td>0.946400</td>
#     </tr>
#     <tr>
#       <td>37000</td>
#       <td>0.952700</td>
#     </tr>
#     <tr>
#       <td>37500</td>
#       <td>0.956200</td>
#     </tr>
#     <tr>
#       <td>38000</td>
#       <td>0.953300</td>
#     </tr>
#     <tr>
#       <td>38500</td>
#       <td>0.956000</td>
#     </tr>
#     <tr>
#       <td>39000</td>
#       <td>0.961600</td>
#     </tr>
#     <tr>
#       <td>39500</td>
#       <td>0.967400</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>0.958500</td>
#     </tr>
#     <tr>
#       <td>40500</td>
#       <td>0.950900</td>
#     </tr>
#     <tr>
#       <td>41000</td>
#       <td>0.953500</td>
#     </tr>
#     <tr>
#       <td>41500</td>
#       <td>0.951600</td>
#     </tr>
#     <tr>
#       <td>42000</td>
#       <td>0.953600</td>
#     </tr>
#     <tr>
#       <td>42500</td>
#       <td>0.948900</td>
#     </tr>
#     <tr>
#       <td>43000</td>
#       <td>0.954200</td>
#     </tr>
#     <tr>
#       <td>43500</td>
#       <td>0.954200</td>
#     </tr>
#     <tr>
#       <td>44000</td>
#       <td>0.940400</td>
#     </tr>
#     <tr>
#       <td>44500</td>
#       <td>0.945700</td>
#     </tr>
#     <tr>
#       <td>45000</td>
#       <td>0.954100</td>
#     </tr>
#     <tr>
#       <td>45500</td>
#       <td>0.949500</td>
#     </tr>
#     <tr>
#       <td>46000</td>
#       <td>0.951100</td>
#     </tr>
#     <tr>
#       <td>46500</td>
#       <td>0.961400</td>
#     </tr>
#     <tr>
#       <td>47000</td>
#       <td>0.961300</td>
#     </tr>
#     <tr>
#       <td>47500</td>
#       <td>0.949000</td>
#     </tr>
#     <tr>
#       <td>48000</td>
#       <td>0.938000</td>
#     </tr>
#     <tr>
#       <td>48500</td>
#       <td>0.949800</td>
#     </tr>
#     <tr>
#       <td>49000</td>
#       <td>0.956500</td>
#     </tr>
#     <tr>
#       <td>49500</td>
#       <td>0.948700</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>0.954100</td>
#     </tr>
#     <tr>
#       <td>50500</td>
#       <td>0.952900</td>
#     </tr>
#     <tr>
#       <td>51000</td>
#       <td>0.953100</td>
#     </tr>
#     <tr>
#       <td>51500</td>
#       <td>0.949800</td>
#     </tr>
#     <tr>
#       <td>52000</td>
#       <td>0.950200</td>
#     </tr>
#     <tr>
#       <td>52500</td>
#       <td>0.956400</td>
#     </tr>
#     <tr>
#       <td>53000</td>
#       <td>0.944700</td>
#     </tr>
#     <tr>
#       <td>53500</td>
#       <td>0.949200</td>
#     </tr>
#     <tr>
#       <td>54000</td>
#       <td>0.944500</td>
#     </tr>
#     <tr>
#       <td>54500</td>
#       <td>0.949900</td>
#     </tr>
#     <tr>
#       <td>55000</td>
#       <td>0.950700</td>
#     </tr>
#     <tr>
#       <td>55500</td>
#       <td>0.960400</td>
#     </tr>
#     <tr>
#       <td>56000</td>
#       <td>0.946400</td>
#     </tr>
#     <tr>
#       <td>56500</td>
#       <td>0.947500</td>
#     </tr>
#     <tr>
#       <td>57000</td>
#       <td>0.941800</td>
#     </tr>
#     <tr>
#       <td>57500</td>
#       <td>0.955900</td>
#     </tr>
#     <tr>
#       <td>58000</td>
#       <td>0.947700</td>
#     </tr>
#     <tr>
#       <td>58500</td>
#       <td>0.939200</td>
#     </tr>
#     <tr>
#       <td>59000</td>
#       <td>0.955000</td>
#     </tr>
#     <tr>
#       <td>59500</td>
#       <td>0.951100</td>
#     </tr>
#     <tr>
#       <td>60000</td>

# %%
# 모델 학습 결과 저장
trainer.save_model("/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/model/llama_finetuned")
tokenizer.save_pretrained("/home/dnslabs/jupyter-server-workspace/Ryumyungjae_Workspace/Book_ai/model/llama_finetuned")

# 메모리 정리
del model, train_dataset, eval_dataset, final_tokenized_dataset
gc.collect()
torch.cuda.empty_cache()
